# %%
# !pip install -q kaggle

# %%
from google.colab import files # kaggle'dan aldığımız kaggle.json'u upload ediyorum.
files.upload()

# %%
# !mkdir ~/.kaggle #dizinde kaggle klasörü oluşturuyorum.
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !cp kaggle.json ~/.kaggle/ # upload ettiğim kaggle.json'u kaggle klasörüne gönderiyorum.

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c gdz-elektrik-datathon-2023
# Out:
# ...
# 100% 483k/483k [00:00<00:00, 875kB/s]
# 100% 483k/483k [00:00<00:00, 874kB/s]

# %%
# !unzip gdz-elektrik-datathon-2023.zip
# Out:
# Archive:  gdz-elektrik-datathon-2023.zip
#   inflating: med.csv
#   inflating: sample_submission.csv
#   inflating: train.csv

# %%
import pandas as pd
med = pd.read_csv("/content/med.csv")
train = pd.read_csv("/content/train.csv")
submission = pd.read_csv("/content/sample_submission.csv")

# %%
med.to_csv("/content/drive/MyDrive/gdz_elektrik/kaggle/test.csv",index=False)
train.to_csv("/content/drive/MyDrive/gdz_elektrik/kaggle/train.csv",index=False)
submission.to_csv("/content/drive/MyDrive/gdz_elektrik/kaggle/sample_submission.csv",index=False)
